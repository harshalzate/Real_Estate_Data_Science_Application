# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('flats.csv')
df.sample(5)
# Out:
#                         property_name  \
# 2912  1 BHK Flat in Sector 95 Gurgaon
# 2467        3 BHK Flat in IFFCO Chowk
# 872   3 BHK Flat in Sector 63 Gurgaon
# 1607  4 BHK Flat in Sector 70 Gurgaon
# 1451              3 BHK Flat in Sohna
#
#                                                    link  \
# 2912  https://www.99acres.com/1-bhk-bedroom-apartmen...
# 2467  https://www.99acres.com/3-bhk-bedroom-apartmen...
# 872   https://www.99acres.com/3-bhk-bedroom-apartmen...
# 1607  https://www.99acres.com/4-bhk-bedroom-apartmen...
# 1451  https://www.99acres.com/3-bhk-bedroom-apartmen...
#
#                          society       price             area  \
# 2912                  ROF Ananda      26 Lac   ₹ 6,842/sq.ft.
# 2467                 essel tower  1.85 Crore  ₹ 11,859/sq.ft.
# 872    Dhoot Time Residency4.0 ★   2.2 Crore  ₹ 12,813/sq.ft.
# 1607            Tulip Ivory3.5 ★   2.1 Crore   ₹ 8,750/sq.ft.
# 1451  Signature Global Park4.0 ★      78 Lac   ₹ 6,446/sq.ft.
#
# ...

# %%
# shape
df.shape
# Out:
# (3016, 20)

# %%
# info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3016 entries, 0 to 3015
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3016 non-null   object
#  1   link             3016 non-null   object
#  2   society          3015 non-null   object
#  3   price            3006 non-null   object
#  4   area             3003 non-null   object
#  5   areaWithType     3007 non-null   object
#  6   bedRoom          3007 non-null   object
#  7   bathroom         3007 non-null   object
#  8   balcony          3007 non-null   object
#  9   additionalRoom   1693 non-null   object
#  10  address          3001 non-null   object
#  11  floorNum         3005 non-null   object
#  12  facing           2126 non-null   object
#  13  agePossession    3006 non-null   object
#  14  nearbyLocations  2912 non-null   object
#  15  description      3007 non-null   object
# ...

# %%
# check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# check for missing values
df.isnull().sum()
# Out:
# property_name         0
# link                  0
# society               1
# price                10
# area                 13
# areaWithType          9
# bedRoom               9
# bathroom              9
# balcony               9
# additionalRoom     1323
# address              15
# floorNum             11
# facing              890
# agePossession        10
# nearbyLocations     104
# description           9
# furnishDetails      814
# features            423
# rating              341
# property_id           9
# dtype: int64

# %%
# Columns to drop -> property_name, link, property_id
df.drop(columns=['link','property_id'], inplace=True)

# %%
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave      50 Lac
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend      70 Lac
#
#               area                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %%
# rename columns area to price_per_sqft
df.rename(columns={'area':'price_per_sqft'},inplace=True)
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave      50 Lac
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend      70 Lac
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %%
# society
df['society'].value_counts()
# Out:
# SS The Leaf3.8 ★                                     73
# Tulip Violet4.3 ★                                    40
# Shapoorji Pallonji Joyville Gurugram4.0 ★            39
# Signature Global Park4.0 ★                           36
# Shree Vardhman Victoria3.8 ★                         35
# Tulip Violet4.2 ★                                    33
# Smart World Gems                                     32
# Smart World Orchard                                  32
# Emaar MGF Emerald Floors Premier3.8 ★                32
# DLF The Ultima4.0 ★                                  31
# Paras Dews                                           31
# DLF Regal Gardens3.9 ★                               30
# M3M Woodshire4.0 ★                                   29
# Shree Vardhman Flora3.8 ★                            29
# Signature Global Solera3.7 ★                         28
# La Vida by Tata Housing                              28
# Godrej Nature Plus                                   27
# ...

# %%
df['society'].value_counts().shape
# Out:
# (638,)

# %%
# Text cleaning of the society names
import re
df['society'] = df['society'].apply(lambda name: re.sub(r'\d+(\.\d+)?\s?★', '', str(name)).strip()).str.lower()

# %%
df['society']
# Out:
# 0                              maa bhagwati residency
# 1                                        apna enclave
# 2                              tulsiani easy in homes
# 3                                 smart world orchard
# 4                                    parkwood westend
# 5                      signature global infinity mall
# 6                                          the cocoon
# 7                                         ats triumph
# 8                                   vatika xpressions
# 9                                      raheja revanta
# 10                           signature global city 81
# 11                                  hcbs sports ville
# 12                                 supertech araville
# 13                                             godrej
# 14                               shree vardhman flora
# 15                                         sobha city
# 16                                       senate court
# ...

# %%
df['society'].value_counts().shape
# Out:
# (604,)

# %%
df['society'].value_counts()
# Out:
# tulip violet                                     75
# ss the leaf                                      74
# shapoorji pallonji joyville gurugram             45
# dlf new town heights                             38
# signature global park                            36
# shree vardhman victoria                          35
# smart world orchard                              32
# emaar mgf emerald floors premier                 32
# smart world gems                                 32
# paras dews                                       31
# dlf the ultima                                   31
# m3m woodshire                                    30
# dlf regal gardens                                30
# shree vardhman flora                             29
# la vida by tata housing                          28
# signature global solera                          28
# godrej nature plus                               27
# emaar gurgaon greens                             25
# ...

# %%
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            apna enclave      50 Lac
# 2              2 BHK Flat in Sohna  tulsiani easy in homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend      70 Lac
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %%
# price
# Remove rows with price as Price on Request
df['price'].value_counts()
# Out:
# 1.25 Crore          79
# 1.1 Crore           61
# 1.4 Crore           60
# 1.5 Crore           59
# 1.2 Crore           59
# 90 Lac              58
# 1.3 Crore           57
# 95 Lac              53
# 2 Crore             51
# 1.75 Crore          47
# 1 Crore             46
# 1.6 Crore           43
# 1.35 Crore          41
# 1.55 Crore          40
# 1.9 Crore           40
# 1.65 Crore          38
# 75 Lac              38
# 1.8 Crore           37
# 1.7 Crore           37
# 80 Lac              36
# 2.2 Crore           34
# 50 Lac              33
# 1.15 Crore          33
# 85 Lac              31
# 1.45 Crore          31
# 1.05 Crore          30
# 60 Lac              29
# 40 Lac              29
# 2.5 Crore           29
# 45 Lac              26
# 2.1 Crore           26
# 65 Lac              25
# 35 Lac              23
# 2.35 Crore          23
# 1.85 Crore          23
# 3 Crore             22
# 70 Lac              21
# 55 Lac              20
# 2.25 Crore          20
# 3.5 Crore           19
# ...

# %%
df[df['price'] == 'Price on Request']
# Out:
#                          property_name                    society  \
# 25      5 BHK Flat in Sector 1 Gurgaon  the new people apartments
# 1643   4 BHK Flat in Sector 50 Gurgaon                ss hibiscus
# 1971   1 BHK Flat in Sector 31 Gurgaon            raheja atlantis
# 2053   2 BHK Flat in Sector 79 Gurgaon         supertech araville
# 2356  2 BHK Flat in Sector 37D Gurgaon            the millennia 2
# 2521  2 BHK Flat in Sector 95A Gurgaon              the roselia 2
# 2548      3 BHK Flat in Sector-2 Sohna         supertech hilltown
# 2639  2 BHK Flat in Sector 95A Gurgaon              the roselia 2
# 2958  3 BHK Flat in Sector 104 Gurgaon              godrej summit
# 2971         4 BHK Flat in Gwal Pahari     krrish provence estate
# 2972   4 BHK Flat in Sector 95 Gurgaon    sidhartha ncr one phase
#
#                  price price_per_sqft  \
# 25    Price on Request            NaN
# 1643  Price on Request            NaN
# 1971  Price on Request            NaN
# ...

# %%
df[df['price'] == 'Price on Request'].shape
# Out:
# (11, 18)

# %%
df = df[df['price'] != 'Price on Request']

# %%
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            apna enclave      50 Lac
# 2              2 BHK Flat in Sohna  tulsiani easy in homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend      70 Lac
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %%
def treat_price(x):
  ## price into a cores with float data type
    if type(x) == float:
        return x
    else:
        if x[1] == 'Lac':
            return round(float(x[0])/100,2)
        else:
            return round(float(x[0]),2)

# %%
df['price'] = df['price'].str.split(' ').apply(treat_price)
# Out:
# <ipython-input-92-45c08249b2fd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'].str.split(' ').apply(treat_price)

# %%
df.head(5)
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# 1  2 Bathrooms    1 Balcony            NaN
# ...

# %%
# price_per_sqft
# Extract the exact number
df['price_per_sqft'].value_counts()
# Out:
# ₹ 10,000/sq.ft.     19
# ₹ 8,000/sq.ft.      16
# ₹ 12,500/sq.ft.     16
# ₹ 6,666/sq.ft.      13
# ₹ 5,000/sq.ft.      13
# ₹ 7,500/sq.ft.      12
# ₹ 8,333/sq.ft.      12
# ₹ 6,000/sq.ft.      11
# ₹ 8,461/sq.ft.       9
# ₹ 12,000/sq.ft.      8
# ₹ 7,000/sq.ft.       8
# ₹ 9,000/sq.ft.       7
# ₹ 9,230/sq.ft.       6
# ₹ 8,928/sq.ft.       6
# ₹ 5,500/sq.ft.       6
# ₹ 11,500/sq.ft.      6
# ₹ 6,578/sq.ft.       6
# ₹ 11,111/sq.ft.      6
# ₹ 8,888/sq.ft.       6
# ₹ 5,556/sq.ft.       5
# ₹ 7,641/sq.ft.       5
# ₹ 7,407/sq.ft.       5
# ₹ 10,714/sq.ft.      5
# ₹ 7,142/sq.ft.       5
# ₹ 14,242/sq.ft.      5
# ₹ 5,384/sq.ft.       5
# ₹ 4,666/sq.ft.       5
# ₹ 4,615/sq.ft.       5
# ₹ 16,000/sq.ft.      5
# ₹ 8,571/sq.ft.       5
# ₹ 8,205/sq.ft.       5
# ₹ 4,444/sq.ft.       5
# ₹ 6,500/sq.ft.       5
# ₹ 11,428/sq.ft.      5
# ₹ 7,692/sq.ft.       5
# ₹ 5,600/sq.ft.       5
# ₹ 8,043/sq.ft.       4
# ₹ 5,660/sq.ft.       4
# ₹ 13,913/sq.ft.      4
# ₹ 6,250/sq.ft.       4
# ...

# %%
# Extracting Exact price from the price_per_sqft
df['price_per_sqft'] = df['price_per_sqft'].str.split('/').str.get(0).str.replace('₹','').str.replace(',','').str.strip().astype('float')

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType     bedRoom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# 1  2 Bathrooms    1 Balcony            NaN
# ...

# %%
# bedrooms
# Remove Null values and Extract number
df['bedRoom'].value_counts()
# Out:
# 3 Bedrooms    1436
# 2 Bedrooms     944
# 4 Bedrooms     478
# 1 Bedroom      104
# 5 Bedrooms      31
# 6 Bedrooms       3
# Name: bedRoom, dtype: int64

# %%
df[df['bedRoom'].isnull()]
# Out:
#                                   property_name                       society  \
# 2848           2 BHK Flat in Sector 107 Gurgaon       signature global solera
# 2849            4 BHK Flat in Sector 53 Gurgaon                tulip monsella
# 2850              2 BHK Flat in New Palam Vihar                       my home
# 2851                        2 BHK Flat in Sohna        breez global hill view
# 2921           3 BHK Flat in Sector 99A Gurgaon      pareena coban residences
# 2922         1 BHK Flat in Golf Course Ext Road  ikon tower baani city centre
# 2923            2 BHK Flat in Sector 89 Gurgaon                   greenopolis
# 2925  4 BHK Flat in C Block Sushant Lok Phase 1                 maple heights
# 2926            2 BHK Flat in Sector 99 Gurgaon                assotech blith
#
#       price  price_per_sqft areaWithType bedRoom bathroom balcony  \
# 2848    NaN             NaN          NaN     NaN      NaN     NaN
# ...

# %%
df['bedRoom'].isnull().sum()
# Out:
# 9

# %%
df = df[~df['bedRoom'].isnull()]

# %%
df['bedRoom'] = df['bedRoom'].str.split(' ').str.get(0).astype('int')
# Out:
# <ipython-input-101-b410b527b8ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bedRoom'] = df['bedRoom'].str.split(' ').str.get(0).astype('int')

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# 1  2 Bathrooms    1 Balcony            NaN
# ...

# %%
# bathroom
# Extract number
df['bathroom'].value_counts()
# Out:
# 2 Bathrooms    1044
# 3 Bathrooms     989
# 4 Bathrooms     636
# 5 Bathrooms     168
# 1 Bathroom      112
# 6 Bathrooms      42
# 7 Bathrooms       5
# Name: bathroom, dtype: int64

# %%
df['bathroom'].isnull().sum()
# Out:
# 0

# %%
df['bathroom'] = df['bathroom'].str.split(' ').str.get(0).astype('int')

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2         2
#
#        balcony additionalRoom                              address  \
# ...

# %%
# balcony
# Extract number
df['balcony'].value_counts()
# Out:
# 3 Balconies     974
# 3+ Balconies    861
# 2 Balconies     749
# 1 Balcony       315
# No Balcony       97
# Name: balcony, dtype: int64

# %%
df['balcony'].isnull().sum()
# Out:
# 0

# %%
df['balcony'] = df['balcony'].str.split(' ').str.get(0).str.replace('No','0')

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2         2
#
#   balcony additionalRoom                              address  \
# ...

# %%
# additionalRoom
# Fill Null values with Not Available and into lower cases
df['additionalRoom'].value_counts()
# Out:
# Servant Room                                     628
# Study Room                                       232
# Others                                           179
# Pooja Room                                       132
# Study Room,Servant Room                           81
# Store Room                                        76
# Pooja Room,Servant Room                           60
# Servant Room,Others                               52
# Servant Room,Pooja Room                           30
# Study Room,Others                                 27
# Pooja Room,Study Room,Servant Room,Others         25
# Pooja Room,Study Room,Servant Room                24
# Servant Room,Store Room                           19
# Pooja Room,Study Room                             13
# Pooja Room,Study Room,Servant Room,Store Room     12
# Study Room,Pooja Room                              8
# Servant Room,Study Room                            8
# Study Room,Servant Room,Store Room                 7
# ...

# %%
df['additionalRoom'].value_counts().shape
# Out:
# (49,)

# %%
df['additionalRoom'].isnull().sum()
# Out:
# 1305

# %%
df['additionalRoom'].fillna('not available',inplace=True)

# %%
df['additionalRoom'] = df['additionalRoom'].str.lower()

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2         2
#
#   balcony additionalRoom                              address  \
# ...

# %%
df['floorNum'].describe()
# Out:
# count                  2994
# unique                  549
# top       2nd   of 4 Floors
# freq                     74
# Name: floorNum, dtype: object

# %%
# floor num
# Extracting the floor number
df['floorNum']
# Out:
# 0              4th   of 4 Floors
# 1              1st   of 3 Floors
# 2            12nd   of 14 Floors
# 3              2nd   of 4 Floors
# 4              5th   of 8 Floors
# 5              3rd   of 3 Floors
# 6             5th   of 25 Floors
# 7            14th   of 27 Floors
# 8              2nd   of 3 Floors
# 9            31st   of 40 Floors
# 10             1st   of 4 Floors
# 11            4th   of 13 Floors
# 12            4th   of 15 Floors
# 13            3rd   of 20 Floors
# 14           13rd   of 13 Floors
# 15           25th   of 25 Floors
# 16            Ground of 1 Floors
# 17           Ground of 14 Floors
# 18           11st   of 14 Floors
# 19           12nd   of 13 Floors
# 20             4th   of 4 Floors
# 21           11st   of 22 Floors
# 22             4th   of 4 Floors
# 23           Ground of 14 Floors
# 24           10th   of 25 Floors
# 26             3rd   of 3 Floors
# 27           20th   of 20 Floors
# 28            5th   of 17 Floors
# ...

# %%
df['floorNum'].isnull().sum()
# Out:
# 2

# %%
df['floorNum'] = df['floorNum'].str.split(' ').str.get(0).replace('Ground','0').str.replace('Basement','-1').str.replace('Lower','0').str.extract(r'(\d+)')

# %%
df.iloc[182,:]
# Out:
# property_name                        1 BHK Flat in Sector 67 Gurgaon
# society                                                   m3m urbana
# price                                                            1.0
# price_per_sqft                                               12106.0
# areaWithType                        Built Up area: 826 (76.74 sq.m.)
# bedRoom                                                            1
# bathroom                                                           1
# balcony                                                            1
# additionalRoom                                         not available
# address                          Sector 67 Gurgaon, Gurgaon, Haryana
# floorNum                                                          17
# facing                                                         South
# agePossession                                        1 to 5 Year Old
# nearbyLocations    ['Sri Radhe Krishna Temple', 'Kamal Hospital a...
# ...

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2         2
#
#   balcony additionalRoom                              address floorNum facing  \
# ...

# %%
# facing
# -- Fill NA in missing values
df['facing'].value_counts()
# Out:
# North-East    505
# East          490
# North         301
# South         203
# West          182
# North-West    162
# South-East    144
# South-West    135
# Name: facing, dtype: int64

# %%
df['facing'].isnull().sum()
# Out:
# 874

# %%
df['facing'].fillna('NA',inplace=True)

# %%
df['facing'].value_counts()
# Out:
# NA            874
# North-East    505
# East          490
# North         301
# South         203
# West          182
# North-West    162
# South-East    144
# South-West    135
# Name: facing, dtype: int64

# %%
df_flats=df.copy()

# %%
# Insert a column for Area
df_flats.insert(loc=4,column='area',value=round((df['price']*10000000)/df['price_per_sqft']))

# %%
# Insert a column for property type
df_flats.insert(loc=1,column='property_type',value='flat')

# %%
df_flats.to_csv('flats_cleaned.csv',index=False)

# %% [markdown]
# # Houses

# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('houses.csv')
df.sample(5)
# Out:
#                                      property_name  \
# 24         9 Bedroom House for sale in DLF Phase 2
# 537   6 Bedroom House for sale in Sector 1 Gurgaon
# 323     34 Bedroom House for sale in Manohar Nagar
# 984  8 Bedroom House for sale in Sector 17 Gurgaon
# 659   12 Bedroom House for sale in Uppals Southend
#
#                                                   link              society  \
# 24   https://www.99acres.com/9-bhk-bedroom-independ...                  NaN
# 537  https://www.99acres.com/6-bhk-bedroom-independ...                  NaN
# 323  https://www.99acres.com/34-bhk-bedroom-indepen...        MANOHAR NAGAR
# 984  https://www.99acres.com/8-bhk-bedroom-independ...                  NaN
# 659  https://www.99acres.com/12-bhk-bedroom-indepen...  Uppal Southend4.0 ★
#
#           price             rate                       area  \
# 24    7.6 Crore  ₹ 38,760/sq.ft.      (180 sq.m.) Plot Area
# 537  4.75 Crore  ₹ 10,556/sq.ft.  (418 sq.m.) Built-up Area
# ...

# %%
df.head()
# Out:
#                                       property_name  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon
# 1  5 Bedroom House for sale in Sector 21A Faridabad
# 2  10 Bedroom House for sale in Sushant Lok Phase 1
# 3    21 Bedroom House for sale in Sector 54 Gurgaon
# 4  12 Bedroom House for sale in Sushant Lok Phase 1
#
#                                                 link           society  \
# 0  https://www.99acres.com/5-bhk-bedroom-independ...  Bptp Visionnaire
# 1  https://www.99acres.com/5-bhk-bedroom-independ...               NaN
# 2  https://www.99acres.com/10-bhk-bedroom-indepen...               NaN
# 3  https://www.99acres.com/21-bhk-bedroom-indepen...               NaN
# 4  https://www.99acres.com/12-bhk-bedroom-indepen...               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    1044 non-null   object
#  1   link             1044 non-null   object
#  2   society          453 non-null    object
#  3   price            968 non-null    object
#  4   rate             1005 non-null   object
#  5   area             1044 non-null   object
#  6   areaWithType     987 non-null    object
#  7   bedRoom          987 non-null    object
#  8   bathroom         987 non-null    object
#  9   balcony          987 non-null    object
#  10  additionalRoom   589 non-null    object
#  11  address          1031 non-null   object
#  12  noOfFloor        967 non-null    object
#  13  facing           674 non-null    object
#  14  agePossession    987 non-null    object
#  15  nearbyLocations  913 non-null    object
# ...

# %%
df.shape
# Out:
# (1044, 21)

# %%
# info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    1044 non-null   object
#  1   link             1044 non-null   object
#  2   society          453 non-null    object
#  3   price            968 non-null    object
#  4   rate             1005 non-null   object
#  5   area             1044 non-null   object
#  6   areaWithType     987 non-null    object
#  7   bedRoom          987 non-null    object
#  8   bathroom         987 non-null    object
#  9   balcony          987 non-null    object
#  10  additionalRoom   589 non-null    object
#  11  address          1031 non-null   object
#  12  noOfFloor        967 non-null    object
#  13  facing           674 non-null    object
#  14  agePossession    987 non-null    object
#  15  nearbyLocations  913 non-null    object
# ...

# %%
# check for duplicates
df.duplicated().sum()
# Out:
# 13

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (1031, 21)

# %%
# check for missing values
df.isnull().sum()
# Out:
# property_name        0
# link                 0
# society            586
# price               76
# rate                39
# area                 0
# areaWithType        57
# bedRoom             57
# bathroom            57
# balcony             57
# additionalRoom     453
# address             13
# noOfFloor           76
# facing             369
# agePossession       57
# nearbyLocations    131
# description          8
# furnishDetails     299
# features           369
# rating             137
# property_id          8
# dtype: int64

# %%
# Columns to drop -> property_name, link, property_id
df.drop(columns=['link','property_id'], inplace=True)

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               NaN
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %%
# rename columns  --> rate to price_per_sqft
df.rename(columns={'rate':'price_per_sqft'},inplace=True)
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               NaN
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               NaN
#
#         price    price_per_sqft                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %%
# society
# --> Extract Society names and replce nan with indpendent
df['society'].value_counts()
# Out:
# International City by SOBHA Phase 2                  26
# Emaar MGF Marbella                                   26
# Vipul Tatvam Villa                                   24
# International City by Sobha Phase 1                  23
# Unitech Uniworld Resorts                             13
# DLF City Plots                                       11
# DLF City Plots Phase 2                               11
# Unitech Espace                                       11
# Eldeco Mansionz                                       9
# Bptp Visionnaire                                      8
# Not Applicable                                        7
# Uppal Southend4.0 ★                                   7
# Sushant Lok 1 Builder Floors                          6
# Ansals Palam Vihar                                    6
# DLF City Phase 1                                      5
# Experion Windchants3.8 ★                              5
# DLF Alameda                                           4
# ...

# %%
df['society'].value_counts().shape
# Out:
# (185,)

# %%
import re
df['society'] = df['society'].apply(lambda name: re.sub(r'\d+(\.\d+)?\s?★', '', str(name)).strip()).str.lower()

# %%
df['society'].value_counts().shape
# Out:
# (183,)

# %%
df['society'] = df['society'].str.replace('nan','independent')

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent
#
#         price    price_per_sqft                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %%
# price
# --> Remove price on request
# --> Extract price and convert into float type of crores
df['price'].value_counts()
# Out:
# 3.5 Crore           19
# 5.5 Crore           17
# 6.5 Crore           16
# 6 Crore             14
# 5 Crore             13
# 4.5 Crore           13
# 70 Lac              13
# 8 Crore             13
# 50 Lac              13
# 75 Lac              13
# 8.5 Crore           12
# 7 Crore             12
# 85 Lac              12
# 1.5 Crore           11
# 4 Crore             11
# 10 Crore            10
# Price on Request    10
# 45 Lac              10
# 2.25 Crore          10
# 2.5 Crore           10
# 60 Lac              10
# 90 Lac              10
# 9 Crore             10
# 9.5 Crore            9
# 12 Crore             9
# 80 Lac               9
# 1.7 Crore            9
# 2 Crore              9
# 1.1 Crore            9
# 1 Crore              8
# 6.75 Crore           8
# 11 Crore             8
# 1.6 Crore            8
# 4.6 Crore            8
# 1.3 Crore            7
# 95 Lac               7
# 12.5 Crore           7
# 3.75 Crore           7
# 1.2 Crore            7
# 55 Lac               7
# ...

# %%
df = df[df['price'] != 'Price on Request']

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent
#
#         price    price_per_sqft                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %%
def treat_price(x):
  # price into crores
    if type(x) == float:
        return x
    else:
        if x[1] == 'Lac':
            return round(float(x[0])/100,2)
        else:
            return round(float(x[0]),2)

# %%
df['price'] = df['price'].str.split(' ').apply(treat_price)
# Out:
# <ipython-input-157-45c08249b2fd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'].str.split(' ').apply(treat_price)

# %%
df.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#      price_per_sqft                   area                 areaWithType  \
# 0   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#        bedRoom      bathroom       balcony  \
# ...

# %%
# price_per_sqft
# --> Extract value and convert to float type
df['price_per_sqft'].value_counts()
# Out:
# ₹ 22,222/sq.ft.     14
# ₹ 11,111/sq.ft.     11
# ₹ 33,333/sq.ft.     11
# ₹ 10,000/sq.ft.     10
# ₹ 26,667/sq.ft.      6
# ₹ 13,333/sq.ft.      6
# ₹ 37,037/sq.ft.      6
# ₹ 26,235/sq.ft.      6
# ₹ 30,556/sq.ft.      6
# ₹ 31,481/sq.ft.      6
# ₹ 9,444/sq.ft.       5
# ₹ 23,333/sq.ft.      5
# ₹ 23,148/sq.ft.      5
# ₹ 11,100/sq.ft.      5
# ₹ 8,000/sq.ft.       5
# ₹ 8,889/sq.ft.       5
# ₹ 5,000/sq.ft.       5
# ₹ 35,000/sq.ft.      4
# ₹ 32,407/sq.ft.      4
# ₹ 9,722/sq.ft.       4
# ₹ 18,889/sq.ft.      4
# ₹ 24,691/sq.ft.      4
# ₹ 25,000/sq.ft.      4
# ₹ 27,778/sq.ft.      4
# ₹ 21,605/sq.ft.      4
# ₹ 34,722/sq.ft.      4
# ₹ 6,944/sq.ft.       4
# ₹ 36,111/sq.ft.      3
# ₹ 13,889/sq.ft.      3
# ₹ 20,000/sq.ft.      3
# ₹ 16,058/sq.ft.      3
# ₹ 8,235/sq.ft.       3
# ₹ 60,000/sq.ft.      3
# ₹ 12,222/sq.ft.      3
# ₹ 8,333/sq.ft.       3
# ₹ 14,815/sq.ft.      3
# ₹ 12,000/sq.ft.      3
# ₹ 6,666/sq.ft.       3
# ₹ 15,555/sq.ft.      3
# ₹ 10,556/sq.ft.      3
# ...

# %%
df['price_per_sqft'] = df['price_per_sqft'].str.split('/').str.get(0).str.replace('₹','').str.replace(',','').str.strip().astype('float')
# Out:
# <ipython-input-160-52532a938979>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_per_sqft'] = df['price_per_sqft'].str.split('/').str.get(0).str.replace('₹','').str.replace(',','').str.strip().astype('float')

# %%
df.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3         43066.0  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4         53763.0   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#        bedRoom      bathroom       balcony  \
# ...

# %%
# bedrooms
# --> Remove null and Extract values
df['bedRoom'].value_counts()
# Out:
# 4 Bedrooms     232
# 5 Bedrooms     194
# 3 Bedrooms     146
# 2 Bedrooms      88
# 6 Bedrooms      81
# 9 Bedrooms      45
# 1 Bedroom       38
# 8 Bedrooms      33
# 7 Bedrooms      31
# 12 Bedrooms     28
# 10 Bedrooms     21
# 16 Bedrooms     12
# 13 Bedrooms      4
# 18 Bedrooms      2
# 19 Bedrooms      2
# 11 Bedrooms      2
# 20 Bedrooms      1
# 21 Bedrooms      1
# 36 Bedrooms      1
# 34 Bedrooms      1
# 14 Bedrooms      1
# Name: bedRoom, dtype: int64

# %%
df[df['bedRoom'].isnull()].shape
# Out:
# (57, 19)

# %%
df = df[~df['bedRoom'].isnull()]

# %%
df.shape
# Out:
# (964, 19)

# %%
df['bedRoom'] = df['bedRoom'].str.split(' ').str.get(0).astype('int')
# Out:
# <ipython-input-166-b410b527b8ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bedRoom'] = df['bedRoom'].str.split(' ').str.get(0).astype('int')

# %%
df.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3         43066.0  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4         53763.0   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#    bedRoom      bathroom       balcony                      additionalRoom  \
# ...

# %%
# bathroom
# --> Extract values
df['bathroom'].value_counts()
# Out:
# 4 Bathrooms     228
# 3 Bathrooms     165
# 5 Bathrooms     137
# 2 Bathrooms     114
# 6 Bathrooms      82
# 1 Bathroom       65
# 9 Bathrooms      42
# 7 Bathrooms      39
# 8 Bathrooms      28
# 12 Bathrooms     22
# 10 Bathrooms     11
# 16 Bathrooms      8
# 18 Bathrooms      4
# 13 Bathrooms      4
# 11 Bathrooms      4
# 20 Bathrooms      3
# 17 Bathrooms      3
# 14 Bathrooms      2
# 21 Bathrooms      1
# 36 Bathrooms      1
# 34 Bathrooms      1
# Name: bathroom, dtype: int64

# %%
df['bathroom'].isnull().sum()
# Out:
# 0

# %%
df['bathroom'] = df['bathroom'].str.split(' ').str.get(0).astype('int')
# Out:
# <ipython-input-170-7df10275a800>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bathroom'] = df['bathroom'].str.split(' ').str.get(0).astype('int')

# %%
df.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3         43066.0  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4         53763.0   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#    bedRoom  bathroom       balcony                      additionalRoom  \
# ...

# %%
# balcony
# --> Extract values
df['balcony'].value_counts()
# Out:
# 3+ Balconies    365
# 2 Balconies     220
# 3 Balconies     159
# No Balcony      115
# 1 Balcony       105
# Name: balcony, dtype: int64

# %%
df['balcony'].isnull().sum()
# Out:
# 0

# %%
df['balcony'] = df['balcony'].str.split(' ').str.get(0).str.replace('No','0')

# %%
df.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3         43066.0  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4         53763.0   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#    bedRoom  bathroom balcony                      additionalRoom  \
# ...

# %%
# additionalRoom
# --> Replace Null values by Not available
df['additionalRoom'].value_counts()
# Out:
# Servant Room                                     81
# Pooja Room,Study Room,Servant Room,Store Room    60
# Others                                           58
# Pooja Room                                       38
# Pooja Room,Study Room,Servant Room               33
# Pooja Room,Study Room,Servant Room,Others        32
# Store Room                                       31
# Pooja Room,Servant Room                          24
# Study Room                                       19
# Study Room,Servant Room                          19
# Servant Room,Store Room                          15
# Pooja Room,Study Room                            11
# Pooja Room,Store Room                            11
# Pooja Room,Others                                11
# Servant Room,Pooja Room                           8
# Servant Room,Others                               8
# Pooja Room,Store Room,Study Room,Servant Room     8
# Pooja Room,Servant Room,Store Room                7
# ...

# %%
df['additionalRoom'].fillna('not available',inplace=True)

# %%
df['additionalRoom'] = df['additionalRoom'].str.lower()

# %%
df.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3         43066.0  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4         53763.0   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#    bedRoom  bathroom balcony                      additionalRoom  \
# ...

# %%
# floors
# --> Extract Number of floors
# --> Rename column to floorNum
df['noOfFloor'].value_counts()
# Out:
# 3 Floors     304
# 2 Floors     288
# 1 Floors     181
# 4 Floors     136
# 5 Floors       9
# 0 Floors       6
# 14 Floors      3
# 6 Floors       3
# 11 Floors      2
# 12 Floors      2
# 10 Floors      2
# 16 Floors      1
# 51 Floors      1
# 41 Floors      1
# 27 Floors      1
# 20 Floors      1
# 13 Floors      1
# 21 Floors      1
# 02 Floors      1
# 33 Floors      1
# Name: noOfFloor, dtype: int64

# %%
df['noOfFloor'].isnull().sum()
# Out:
# 19

# %%
df['noOfFloor'] = df['noOfFloor'].str.split(' ').str.get(0)

# %%
df.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3         43066.0  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4         53763.0   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#    bedRoom  bathroom balcony                      additionalRoom  \
# ...

# %%
df.rename(columns={'noOfFloor':'floorNum'},inplace=True)

# %%
df.head()
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent   3.00
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3         43066.0  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4         53763.0   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#    bedRoom  bathroom balcony                      additionalRoom  \
# ...

# %%
# Facing
# Fill Nan by NA
df['facing'].fillna('NA',inplace=True)

# %%
#Area
# --> Add total area column
df['area'] = round((df['price']*10000000)/df['price_per_sqft'])

# %%
# Add column property type
df.insert(loc=1,column='property_type',value='house')

# %%
df.head()
# Out:
#                                       property_name property_type  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon         house
# 1  5 Bedroom House for sale in Sector 21A Faridabad         house
# 2  10 Bedroom House for sale in Sushant Lok Phase 1         house
# 3    21 Bedroom House for sale in Sector 54 Gurgaon         house
# 4  12 Bedroom House for sale in Sushant Lok Phase 1         house
#
#             society  price  price_per_sqft    area  \
# 0  bptp visionnaire   5.25         20115.0  2610.0
# 1       independent   5.70        105751.0   539.0
# 2       independent   2.10         38251.0   549.0
# 3       independent   5.00         43066.0  1161.0
# 4       independent   3.00         53763.0   558.0
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+
# 1   Plot area 539(50.07 sq.m.)        5         4       2
# 2       Plot area 61(51 sq.m.)       10        10      3+
# ...

# %%
df_houses=df.copy()

# %%
df_houses.to_csv('house_cleaned.csv',index=False)

# %% [markdown]
# #Merge Both Files

# %%
df = pd.concat([df_flats,df_houses],ignore_index=True)

# %%
# shuffle the entire data
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                             property_name property_type  \
# 0  2 Bedroom House for sale in Daulatabad         house
# 1         2 BHK Flat in Sector 79 Gurgaon          flat
# 2                     1 BHK Flat in Sohna          flat
# 3         3 BHK Flat in Sector 93 Gurgaon          flat
# 4        2 BHK Flat in Sector 108 Gurgaon          flat
#
#                                        society  price  price_per_sqft    area  \
# 0  secter 16a daultabad faridabad house no 313   0.48         60000.0    80.0
# 1                                       godrej   1.30          8269.0  1572.0
# 2                          trisara our homes 3   0.21          4339.0   484.0
# 3                     spaze privvy the address   1.45          8033.0  1805.0
# 4                       experion the heartsong   0.90          7014.0  1283.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                           Plot area 80(7.43 sq.m.)        2         2
# ...

# %%
df.to_csv('gurgaon_properties.csv',index=False)

# %% [markdown]
# #Combined Preprocessing

# %%
df.sample(5)
# Out:
#                                           property_name property_type  \
# 3529                   3 BHK Flat in Sector 108 Gurgaon          flat
# 3316  5 Bedroom House for sale in A Block Sushant Lo...         house
# 1535                    3 BHK Flat in Sector 56 Gurgaon          flat
# 900                     4 BHK Flat in Sector 91 Gurgaon          flat
# 844      4 Bedroom House for sale in Sector 109 Gurgaon         house
#
#                                   society  price  price_per_sqft    area  \
# 3529                           sobha city   2.50         14611.0  1711.0
# 3316                          independent   9.85         29638.0  3323.0
# 1535                 sukhshanti apartment   1.65          7006.0  2355.0
# 900                            tarc maceo   1.80          7758.0  2320.0
# 844   international city by sobha phase 1   5.75         16428.0  3500.0
#
#                                            areaWithType  bedRoom  bathroom  \
# ...

# %%
df.shape
# Out:
# (3960, 20)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3960 entries, 0 to 3959
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3960 non-null   object
#  1   property_type    3960 non-null   object
#  2   society          3960 non-null   object
#  3   price            3940 non-null   float64
#  4   price_per_sqft   3940 non-null   float64
#  5   area             3940 non-null   float64
#  6   areaWithType     3960 non-null   object
#  7   bedRoom          3960 non-null   int64
#  8   bathroom         3960 non-null   int64
#  9   balcony          3960 non-null   object
#  10  additionalRoom   3960 non-null   object
#  11  address          3949 non-null   object
#  12  floorNum         3939 non-null   object
#  13  facing           3960 non-null   object
#  14  agePossession    3959 non-null   object
#  15  nearbyLocations  3753 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# property_name         0
# property_type         0
# society               0
# price                20
# price_per_sqft       20
# area                 20
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom        0
# address              11
# floorNum             21
# facing                0
# agePossession         1
# nearbyLocations     207
# description           0
# furnishDetails     1032
# features            709
# rating              450
# dtype: int64

# %%
df.head()
# Out:
#                             property_name property_type  \
# 0  2 Bedroom House for sale in Daulatabad         house
# 1         2 BHK Flat in Sector 79 Gurgaon          flat
# 2                     1 BHK Flat in Sohna          flat
# 3         3 BHK Flat in Sector 93 Gurgaon          flat
# 4        2 BHK Flat in Sector 108 Gurgaon          flat
#
#                                        society  price  price_per_sqft    area  \
# 0  secter 16a daultabad faridabad house no 313   0.48         60000.0    80.0
# 1                                       godrej   1.30          8269.0  1572.0
# 2                          trisara our homes 3   0.21          4339.0   484.0
# 3                     spaze privvy the address   1.45          8033.0  1805.0
# 4                       experion the heartsong   0.90          7014.0  1283.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                           Plot area 80(7.43 sq.m.)        2         2
# ...

# %%
# Sector
# --> Add Feature Sector
df.insert(loc=3,column='sector',value=df['property_name'].str.split('in').str.get(1).str.replace('Gurgaon','').str.strip())

# %%
df.head()
# Out:
#                             property_name property_type  \
# 0  2 Bedroom House for sale in Daulatabad         house
# 1         2 BHK Flat in Sector 79 Gurgaon          flat
# 2                     1 BHK Flat in Sohna          flat
# 3         3 BHK Flat in Sector 93 Gurgaon          flat
# 4        2 BHK Flat in Sector 108 Gurgaon          flat
#
#                                        society      sector  price  \
# 0  secter 16a daultabad faridabad house no 313  Daulatabad   0.48
# 1                                       godrej   Sector 79   1.30
# 2                          trisara our homes 3       Sohna   0.21
# 3                     spaze privvy the address   Sector 93   1.45
# 4                       experion the heartsong  Sector 108   0.90
#
#    price_per_sqft    area                                       areaWithType  \
# 0         60000.0    80.0                           Plot area 80(7.43 sq.m.)
# ...

# %%
df['sector'] = df['sector'].str.lower()

# %%
df.head()
# Out:
#                             property_name property_type  \
# 0  2 Bedroom House for sale in Daulatabad         house
# 1         2 BHK Flat in Sector 79 Gurgaon          flat
# 2                     1 BHK Flat in Sohna          flat
# 3         3 BHK Flat in Sector 93 Gurgaon          flat
# 4        2 BHK Flat in Sector 108 Gurgaon          flat
#
#                                        society      sector  price  \
# 0  secter 16a daultabad faridabad house no 313  daulatabad   0.48
# 1                                       godrej   sector 79   1.30
# 2                          trisara our homes 3       sohna   0.21
# 3                     spaze privvy the address   sector 93   1.45
# 4                       experion the heartsong  sector 108   0.90
#
#    price_per_sqft    area                                       areaWithType  \
# 0         60000.0    80.0                           Plot area 80(7.43 sq.m.)
# ...

# %%
df['sector'].value_counts()
# Out:
# sohna                                                        163
# sector 102                                                   113
# sector 85                                                    110
# sector 92                                                    104
# sector 69                                                     94
# sector 65                                                     90
# sector 81                                                     90
# sector 90                                                     90
# sector 109                                                    88
# sector 79                                                     80
# sector 83                                                     69
# sector 37d                                                    68
# sector 86                                                     67
# sector 104                                                    66
# ...

# %%
# replce name with sectors
df['sector'] = df['sector'].str.replace('dharam colony','sector 12')
df['sector'] = df['sector'].str.replace('krishna colony','sector 7')
df['sector'] = df['sector'].str.replace('suncity','sector 54')
df['sector'] = df['sector'].str.replace('prem nagar','sector 13')
df['sector'] = df['sector'].str.replace('mg road','sector 28')
df['sector'] = df['sector'].str.replace('gandhi nagar','sector 28')
df['sector'] = df['sector'].str.replace('laxmi garden','sector 11')
df['sector'] = df['sector'].str.replace('shakti nagar','sector 11')

# %%
df['sector'] = df['sector'].str.replace('baldev nagar','sector 7')
df['sector'] = df['sector'].str.replace('shivpuri','sector 7')
df['sector'] = df['sector'].str.replace('garhi harsaru','sector 17')
df['sector'] = df['sector'].str.replace('imt manesar','manesar')
df['sector'] = df['sector'].str.replace('adarsh nagar','sector 12')
df['sector'] = df['sector'].str.replace('shivaji nagar','sector 11')
df['sector'] = df['sector'].str.replace('bhim nagar','sector 6')
df['sector'] = df['sector'].str.replace('madanpuri','sector 7')

# %%
df['sector'] = df['sector'].str.replace('saraswati vihar','sector 28')
df['sector'] = df['sector'].str.replace('arjun nagar','sector 8')
df['sector'] = df['sector'].str.replace('ravi nagar','sector 9')
df['sector'] = df['sector'].str.replace('vishnu garden','sector 105')
df['sector'] = df['sector'].str.replace('bhondsi','sector 11')
df['sector'] = df['sector'].str.replace('surya vihar','sector 21')
df['sector'] = df['sector'].str.replace('devilal colony','sector 9')
df['sector'] = df['sector'].str.replace('valley view estate','gwal pahari')

# %%
df['sector'] = df['sector'].str.replace('mehrauli  road','sector 14')
df['sector'] = df['sector'].str.replace('jyoti park','sector 7')
df['sector'] = df['sector'].str.replace('ansal plaza','sector 23')
df['sector'] = df['sector'].str.replace('dayanand colony','sector 6')
df['sector'] = df['sector'].str.replace('sushant lok phase 2','sector 55')
df['sector'] = df['sector'].str.replace('chakkarpur','sector 28')
df['sector'] = df['sector'].str.replace('greenwood city','sector 45')
df['sector'] = df['sector'].str.replace('subhash nagar','sector 12')

# %%
df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
df['sector'] = df['sector'].str.replace('malibu town','sector 47')
df['sector'] = df['sector'].str.replace('surat nagar 1','sector 104')
df['sector'] = df['sector'].str.replace('new colony','sector 7')
df['sector'] = df['sector'].str.replace('mianwali colony','sector 12')
df['sector'] = df['sector'].str.replace('jacobpura','sector 12')
df['sector'] = df['sector'].str.replace('rajiv nagar','sector 13')
df['sector'] = df['sector'].str.replace('ashok vihar','sector 3')

# %%
df['sector'] = df['sector'].str.replace('dlf phase 1','sector 26')
df['sector'] = df['sector'].str.replace('nirvana country','sector 50')
df['sector'] = df['sector'].str.replace('palam vihar','sector 2')
df['sector'] = df['sector'].str.replace('dlf phase 2','sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1','sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar','sector 4')
df['sector'] = df['sector'].str.replace('dlf phase 4','sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3','sector 24')

# %%
df['sector'] = df['sector'].str.replace('sushant lok phase 3','sector 57')
df['sector'] = df['sector'].str.replace('dlf phase 5','sector 43')
df['sector'] = df['sector'].str.replace('rajendra park','sector 105')
df['sector'] = df['sector'].str.replace('uppals southend','sector 49')
df['sector'] = df['sector'].str.replace('sohna','sohna road')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
df['sector'] = df['sector'].str.replace('south city 1','sector 41')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2','sector 5')

# %%
# only keep sectors with value counts of greater than 3
a = df['sector'].value_counts()[df['sector'].value_counts() >= 3]
df = df[df['sector'].isin(a.index)]

# %%
df['sector'].value_counts()
# Out:
# sohna road                    163
# sector 102                    113
# sector 85                     110
# sector 92                     104
# sector 69                      94
# sector 65                      90
# sector 90                      90
# sector 81                      90
# sector 109                     88
# sector 79                      80
# sector 104                     73
# sector 83                      69
# sector 37d                     68
# sector 86                      67
# sector 50                      65
# sector 107                     60
# sector 108                     59
# sector 56                      57
# sector 95                      57
# sector 48                      56
# sector 89                      56
# sector 2                       55
# sector 70a                     54
# sector 70                      53
# sector 37c                     53
# sector 43                      53
# sector-33 sohna road           51
# ...

# %%
df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
df['sector'] = df['sector'].str.replace('sector 12a','sector 12')
df['sector'] = df['sector'].str.replace('sector 3a','sector 3')
df['sector'] = df['sector'].str.replace('sector 110 a','sector 110')
df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
df['sector'] = df['sector'].str.replace('a block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('maruti kunj','sector 12')
df['sector'] = df['sector'].str.replace('b block sector 43','sector 43')
# Out:
# <ipython-input-216-fed127d3496f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
# <ipython-input-216-fed127d3496f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
# <ipython-input-216-fed127d3496f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
df['sector'] = df['sector'].str.replace('sector 4 phase 2','sector 4')
df['sector'] = df['sector'].str.replace('sector 1a manesar','manesar')
df['sector'] = df['sector'].str.replace('c block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector 89 a','sector 89')
df['sector'] = df['sector'].str.replace('sector 2 extension','sector 2')
df['sector'] = df['sector'].str.replace('sector 36 sohna road','sector 36')
# Out:
# <ipython-input-217-5a1fa3d4bf64>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
# <ipython-input-217-5a1fa3d4bf64>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
# <ipython-input-217-5a1fa3d4bf64>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df[df['sector'] == 'new']
# Out:
#                   property_name property_type                       society  \
# 176   4 BHK Flat in New Gurgaon          flat                    sare homes
# 538   2 BHK Flat in New Gurgaon          flat  takshila heights sector 37 c
# 2606  2 BHK Flat in New Gurgaon          flat                   green court
# 3893  4 BHK Flat in New Gurgaon          flat                        dlf 76
#
#      sector  price  price_per_sqft    area  \
# 176     new   0.85          4786.0  1776.0
# 538     new   0.67          5583.0  1200.0
# 2606    new   0.38          5507.0   690.0
# 3893    new   4.00         11428.0  3500.0
#
#                                 areaWithType  bedRoom  bathroom balcony  \
# 176      Super Built up area 1776(165 sq.m.)        4         4       3
# 538   Super Built up area 1200(111.48 sq.m.)        2         2       2
# 2606           Carpet area: 690 (64.1 sq.m.)        2         2       1
# 3893        Carpet area: 3500 (325.16 sq.m.)        4         4       2
#
# ...

# %%
# Replace New with correct values manually filling sector
df.loc[955,'sector'] = 'sector 37'
df.loc[2800,'sector'] = 'sector 92'
df.loc[2838,'sector'] = 'sector 90'
df.loc[2857,'sector'] = 'sector 76'

# %%
df[df['sector'] == 'new sector 2']
# Out:
#                                     property_name property_type  \
# 779                 2 BHK Flat in New Palam Vihar          flat
# 1412  3 Bedroom House for sale in New Palam Vihar         house
# 2451                2 BHK Flat in New Palam Vihar          flat
# 2472                2 BHK Flat in New Palam Vihar          flat
# 3880  2 Bedroom House for sale in New Palam Vihar         house
#
#                   society        sector  price  price_per_sqft    area  \
# 779               my home  new sector 2   0.28          3166.0   884.0
# 1412          independent  new sector 2   1.00          8796.0  1137.0
# 2451              my home  new sector 2   0.22          4400.0   500.0
# 2472  ompee k s residency  new sector 2   1.60         26936.0   594.0
# 3880              my home  new sector 2   0.34         12592.0   270.0
#
#                                            areaWithType  bedRoom  bathroom  \
# ...

# %%
# Replace New_Sector 2  with correct values
df.loc[[311,1072,1486,3040,3875],'sector'] = 'sector 110'

# %%
df.shape
# Out:
# (3802, 21)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#                                   property_name property_type  \
# 1               2 BHK Flat in Sector 79 Gurgaon          flat
# 2                           1 BHK Flat in Sohna          flat
# 3               3 BHK Flat in Sector 93 Gurgaon          flat
# 4              2 BHK Flat in Sector 108 Gurgaon          flat
# 5  2 Bedroom House for sale in Sector 5 Gurgaon         house
#
#                     society      sector  price  price_per_sqft    area  \
# 1                    godrej   sector 79   1.30          8269.0  1572.0
# 2       trisara our homes 3  sohna road   0.21          4339.0   484.0
# 3  spaze privvy the address   sector 93   1.45          8033.0  1805.0
# 4    experion the heartsong  sector 108   0.90          7014.0  1283.0
# 5         house number b-34    sector 5   0.80          8888.0   900.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 1             Super Built up area 1572(146.04 sq.m.)        2         2
# ...

# %%
# features to drop -> property_name, address, description, rating
df.drop(columns=['property_name', 'address', 'description', 'rating'],inplace=True)

# %%
df.sample(5)
# Out:
#      property_type                  society      sector  price  \
# 827           flat        dlf regal gardens   sector 90   1.25
# 2133          flat       microtek greenburg   sector 86   1.65
# 3390          flat  signature global solera  sector 107   0.60
# 3592          flat         ansal heights 86   sector 86   0.95
# 3709          flat       supertech araville   sector 79   0.71
#
#       price_per_sqft    area  \
# 827           6459.0  1935.0
# 2133          8707.0  1895.0
# 3390          8000.0   750.0
# 3592          5621.0  1690.0
# 3709          6061.0  1171.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 827   Super Built up area 1703(158.21 sq.m.)Built Up...        3         3
# 2133             Super Built up area 1895(176.05 sq.m.)        3         4
# 3390  Built Up area: 750 (69.68 sq.m.)Carpet area: 6...        3         2
# 3592                   Carpet area: 1690 (157.01 sq.m.)        3         2
# ...

# %%
# feature engineering required -> areaWithType, additionalRoom, facing, agePossession, furnishDetails, features

# %%
df.to_csv('2_gurgaon_properties_cleaned_v1.csv',index=False)
